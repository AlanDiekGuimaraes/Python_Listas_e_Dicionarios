# %% [markdown]
# 01 - Ler uma lista de 5 números inteiros e mostre cada número juntamente com a sia posição na lista.

# %%
lista = [-7,2,20,-4,5]
contador = 1
while contador < len(lista):
    print(f"{contador}:{lista[contador]}")
    contador += 1
# Out:
# 1:2
# 2:20
# 3:-4
# 4:5

# %%
lista = [-7,2,20,-4,5]
contador = 1
for item in lista:
    print(f"{contador}:{item}")
    contador += 1
# Out:
# 1:-7
# 2:2
# 3:20
# 4:-4
# 5:5

# %%
lista = [-7,2,20,-4,5]
for idx, item in enumerate(lista):
    print(f"{idx}:{item}")
# Out:
# 0:-7
# 1:2
# 2:20
# 3:-4
# 4:5

# %% [markdown]
# 02 - Ler uma lista de 10 números reais e mostre-os na ordem inversa que foram lidos.

# %%
lista = [10,7,90,80,25,65,57,26,12,33]
lista.reverse()
print(lista)
# Out:
# [33, 12, 26, 57, 65, 25, 80, 90, 7, 10]

# %% [markdown]
# 03 - Ler uma lista com 5 idades e exibir a maior e a menor.

# %%
idade = [7,36,59,85,16]
print(f"""Menor idade:  {min(idade)}
Maior idade: {max(idade)}""")
# Out:
# Menor idade:  7
# Maior idade: 85

# %% [markdown]
# 04 - 4. Inicialize uma lista de 10 números inteiros. Armazene os números pares em uma lista PAR e os números ímpares em uma lista IMPAR. Imprima as listas PAR e IMPAR.

# %%
lista = [12,95,33,66,80,25,17,28,77,60]
par = [contador for contador in lista if contador % 2 == 0]
impar = [contador for contador in lista if contador % 2 == 1]

print(f"""PARES: {par}
IMPARES:{impar} """)
# Out:
# PARES: [12, 66, 80, 28, 60]
# IMPARES:[95, 33, 25, 17, 77]

# %% [markdown]
# 5. Escreva um programa que troque o primeiro com o último elemento de uma lista qualquer.

# %%
lista = [12,95,33,66,80,25,17,28,77,60]
print([lista[-1]]+lista[1:-1]+[lista[0]])

print("Resultado 01 do professor")
lista[0], lista[-1] = lista[-1], lista[0]
print(lista)

print("Resultado 02 do professor")
primeiro = lista.pop(0)
ultimo = lista.pop()
lista.append(ultimo)
lista.insert(0, primeiro)
print(lista)
# Out:
# [60, 95, 33, 66, 80, 25, 17, 28, 77, 12]
# Resultado 01 do professor
# [60, 95, 33, 66, 80, 25, 17, 28, 77, 12]
# Resultado 02 do professor
# [60, 95, 33, 66, 80, 25, 17, 28, 77, 12]

# %% [markdown]
# 6. Qual a saída/resultado da seguinte compreensão de lista?
# ![image.png](data:image/png;base64,...)
#
# Você consegue entender e explicar o resultado?

# %%
[[1+j*3 + i for i in range(3)] for j in range(3)]



# No problema 06 da atividade de programação tem uma estrutura com 2 for, onde:
# No range i é feita a multiplicação e soma a cada passada no loop, neste caso o i fica responsável por adicionar os elementos na matriz,
# aumentando o i, aumenta a quantidade de itens da matriz.
# No range j é criada as matrizes em si, se aumentar o range do j aumenta a quantidade de matrizes.
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
lista = []
for j in range(3):
  lista.append([])
  for i in range(3):
    lista[j].append(1+j*3 + i)

print(lista)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# RESPOSTA  06
#
# No problema 06 da atividade de programação tem uma estrutura com 2 for, onde:
#
# No range i é feita a multiplicação e soma a cada passada no loop, neste caso o i fica responsável por adicionar os elementos na matriz, aumentando o i, aumenta a quantidade de itens da matriz.
#
# No range j é criada as matrizes em si, se aumentar o range do j aumenta a quantidade de matrizes.

# %% [markdown]
# 7. Considere que você recebe um dicionário contendo informações sobre produtos em uma loja. Cada chave do dicionário é o nome de um produto e cada valor é uma tupla contendo o preço e a quantidade em estoque desse produto.
#
# produtos = {
#
# 'camiseta': (25.00, 10),
#
# 'calça': (45.00, 5),
#
# 'sapato': (60.00, 3),
#
# 'boné': (15.00, 8)
#
# }
#
# Você deve criar um programa em Python que solicite ao usuário que insira um preço máximo. Em seguida, o programa deve imprimir os produtos cujo preço seja menor ou igual ao preço máximo inserido pelo usuário.

# %%
produtos = {'camiseta': (25.00, 10), 'calça': (45.00, 5), 'sapato': (60.00, 3), 'boné': (15.00, 8)}

menor_valor = []

preco = float(input("Digite o valor maximo que deseja que filtremos os produtos: "))

for chave, valor in produtos.items():
  if valor[0] <= preco :
    menor_valor.append(chave)

print(menor_valor)


preco_max =
# Out:
# Digite o valor maximo que deseja que filtremos os produtos: 60
# ['camiseta', 'calça', 'sapato', 'boné']

# %% [markdown]
# 8. Em uma competição de ginástica, cada atleta recebe votos de
# sete jurados. A melhor e a pior nota são eliminadas. A sua nota fica
# sendo a média dos votos restantes. Você deve fazer um programa
# que receba o nome do ginasta e as notas dos sete jurados
# alcançadas pelo atleta em sua apresentação e depois informe a sua
# média, conforme a descrição acima informada (retirar o melhor e o
# pior salto e depois calcular a média com as notas restantes). As
# notas não são informadas em ordem crescente ou decrescente.

# %%
#minha solução
nome = input("Insira o nome do atleta: ").title()
notas = [] # Cria uma lista vazia

for contador in range(1,8): # faz o loop.
  nota = float(input(f"Insira a {contador}ª nota do salto: ")) # Recebe as notas do atleta.
  notas.append(nota) # Adiciona a nota na lista NOTAS
notas.sort()  #Classifica em ordem crecente a lista
notas.pop(0)  # .pop(0) remove o primeiro elemento da lista
notas.pop()   # .pop() remove o ultimo elemento da lista

# notas.remove(max(notas)) # Remove o valor Máximo da lista NOTAS
# notas.remove(min(notas)) # Remove o valor Minimo da lista NOTAS

media = sum(notas)/len(notas) # soma as notas e calcula a média.

print(f"O atleta {nome} teve uma média de {media:.2f} pontos.")
# Out:
# Insira o nome do atleta: alan
# Insira a 1ª nota do salto: 25
# Insira a 2ª nota do salto: 2
# Insira a 3ª nota do salto: 10
# Insira a 4ª nota do salto: 12
# Insira a 5ª nota do salto: 15
# Insira a 6ª nota do salto: 14
# Insira a 7ª nota do salto: 12
# O atleta Alan teve uma média de 12.60 pontos.

# %%
atleta = {
    'nome': '',
    'notas': [],
    'média': 0
}


atleta['nome'] = input('Digite o nome do atleta: ').title()

atleta['notas'] = [float(input('Digite a nota do salto: ')) for i in range(7)]
atleta['notas'].remove(min(atleta['notas']))
atleta['notas'].remove(max(atleta['notas']))

atleta['média'] = sum(atleta['notas']) / len(atleta['notas'])

print(f'\nNome do atleta: {atleta["nome"]}\nNotas: {atleta["notas"]}\nMédia: {atleta["média"]:.2f}')
# Out:
# Digite o nome do atleta: Alan
# Digite a nota do salto: 55
# Digite a nota do salto: 12
# Digite a nota do salto: 24
# Digite a nota do salto: 3
# Digite a nota do salto: 21
# Digite a nota do salto: 7
# Digite a nota do salto: 8
#
# Nome do atleta: Alan
# Notas: [12.0, 24.0, 21.0, 7.0, 8.0]
# Média: 14.40

# %%
atleta = {
    'nome': '',
    'notas': [],
    'média': 0
}

atleta['nome'] = input('Digite o nome do atleta: ').title()

atleta['notas'] = [float(input('Digite a nota do salto: ')) for i in range(7)]
atleta['notas'].sort()
atleta['notas'].pop(0)
atleta['notas'].pop()

atleta['média'] = sum(atleta['notas']) / len(atleta['notas'])

print(f'\nNome do atleta: {atleta["nome"]}\nNotas: {atleta["notas"]}\nMédia: {atleta["média"]:.2f}')
# Out:
# Digite o nome do atleta: alan
# Digite a nota do salto: 25
# Digite a nota do salto: 2
# Digite a nota do salto: 5
# Digite a nota do salto: 4
# Digite a nota do salto: 7
# Digite a nota do salto: 9
# Digite a nota do salto: 6
#
# Nome do atleta: Alan
# Notas: [4.0, 5.0, 6.0, 7.0, 9.0]
# Média: 6.20
